# %%
import pandas as pd

# %%
MainDF = pd.read_csv('C:/Users/ABA/Desktop/nikamooz/mainCourseSTuuf/dataset/revenue-budget-financial-plan.csv')
MainDF.head()
# Out:
#   Publication Date  Fiscal Year Fundind Source Name  FPS Group FPS Group Name  \
# 0       2016 11 17         2017          City Funds          1  Real Property
# 1       2016 11 17         2017          City Funds          1  Real Property
# 2       2016 11 17         2017          City Funds          1  Real Property
# 3       2016 11 17         2017          City Funds          1  Real Property
# 4       2016 11 17         2017          City Funds          1  Real Property
#
#    Agency Number Agency Name  Revenue Category Revenue Category Name  \
# 0            2.0   Mayoralty                20                 TAXES
# 1            2.0   Mayoralty                20                 TAXES
# 2            2.0   Mayoralty                20                 TAXES
# 3            2.0   Mayoralty                20                 TAXES
# 4            2.0   Mayoralty                20                 TAXES
#
#    Revenue Class Code          ...           Revenue Source  \
# ...

# %%
pd.read_csv?

# %%
MainDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3213 entries, 0 to 3212
# Data columns (total 22 columns):
# Publication Date                  3213 non-null object
# Fiscal Year                       3213 non-null int64
# Fundind Source Name               3213 non-null object
# FPS Group                         3213 non-null int64
# FPS Group Name                    3213 non-null object
# Agency Number                     3213 non-null float64
# Agency Name                       3213 non-null object
# Revenue Category                  3213 non-null int64
# Revenue Category Name             3213 non-null object
# Revenue Class Code                3213 non-null float64
# Revenue Class Name                3213 non-null object
# Budget Code                       3213 non-null object
# Revenue Source                    3213 non-null object
# Revenue Source Name               3213 non-null object
# Revenue Structure Description     3213 non-null object
# ...

# %%
MainDF.loc[1:3]
# Out:
#   Publication Date  Fiscal Year Fundind Source Name  FPS Group FPS Group Name  \
# 1       2016 11 17         2017          City Funds          1  Real Property
# 2       2016 11 17         2017          City Funds          1  Real Property
# 3       2016 11 17         2017          City Funds          1  Real Property
#
#    Agency Number Agency Name  Revenue Category Revenue Category Name  \
# 1            2.0   Mayoralty                20                 TAXES
# 2            2.0   Mayoralty                20                 TAXES
# 3            2.0   Mayoralty                20                 TAXES
#
#    Revenue Class Code          ...           Revenue Source  \
# 1                 1.0          ...                    00002
# 2                 1.0          ...                    00003
# 3                 1.0          ...                    00004
#
#        Revenue Source Name  Revenue Structure Description  \
# 1  REAL PROP TAX 2ND QUART        REAL PROP TAX 2ND QUART
# ...

# %%
MainDF1 = pd.read_csv('C:/Users/ABA/Desktop/nikamooz/mainCourseSTuuf/dataset/revenue-budget-financial-plan.csv'
                      , index_col= 'Year 1 Revenue Amount')
MainDF1.head()
# Out:
#                       Publication Date  Fiscal Year Fundind Source Name  \
# Year 1 Revenue Amount
#  10364353000                2016 11 17         2017          City Funds
#  1823017000                 2016 11 17         2017          City Funds
#  9991423000                 2016 11 17         2017          City Funds
#  1866204000                 2016 11 17         2017          City Funds
# -400000000                  2016 11 17         2017          City Funds
#
#                        FPS Group FPS Group Name  Agency Number Agency Name  \
# Year 1 Revenue Amount
#  10364353000                   1  Real Property            2.0   Mayoralty
#  1823017000                    1  Real Property            2.0   Mayoralty
#  9991423000                    1  Real Property            2.0   Mayoralty
#  1866204000                    1  Real Property            2.0   Mayoralty
# -400000000                     1  Real Property            2.0   Mayoralty
#
# ...

# %%
MainDF1.index.name = None
MainDF1.head()
# Out:
#              Publication Date  Fiscal Year Fundind Source Name  FPS Group  \
#  10364353000       2016 11 17         2017          City Funds          1
#  1823017000        2016 11 17         2017          City Funds          1
#  9991423000        2016 11 17         2017          City Funds          1
#  1866204000        2016 11 17         2017          City Funds          1
# -400000000         2016 11 17         2017          City Funds          1
#
#              FPS Group Name  Agency Number Agency Name  Revenue Category  \
#  10364353000  Real Property            2.0   Mayoralty                20
#  1823017000   Real Property            2.0   Mayoralty                20
#  9991423000   Real Property            2.0   Mayoralty                20
#  1866204000   Real Property            2.0   Mayoralty                20
# -400000000    Real Property            2.0   Mayoralty                20
#
#              Revenue Category Name  Revenue Class Code          ...            \
# ...

# %%
sixth_record = MainDF.iloc[5]
sixth_record
# Out:
# Publication Date                                    2016 11 17
# Fiscal Year                                               2017
# Fundind Source Name                                 City Funds
# FPS Group                                                    1
# FPS Group Name                                   Real Property
# Agency Number                                                2
# Agency Name                                          Mayoralty
# Revenue Category                                            20
# Revenue Category Name                                    TAXES
# Revenue Class Code                                           1
# Revenue Class Name                      GENERAL PROPERTY TAXES
# Budget Code                                               0421
# Revenue Source                                           00034
# Revenue Source Name               REAL PROPERTY TAX LIEN SALES
# Revenue Structure Description     REAL PROPERTY TAX LIEN SALES
# ...

# %%
sixthRowColumn = MainDF.iloc[5,5]
sixthRowColumn
# Out:
# 2.0

# %%
isNull = MainDF["Revenue Source"].isnull()
isNotNull = MainDF["Revenue Category"].notnull()
print(isNull.head(),isNotNull.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Revenue Source, dtype: bool 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Revenue Category, dtype: bool

# %% [markdown]
# ##   تمرین: سود سالهای اول و دوم و سوم  آنهایی که کتگوری سود سالانه آنها 20 است

# %%
null_previous_rank = df[df["previous_rank"].isnull()][["....","....", "....."]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-41abec5522a1> in <module>()
# ----> 1 null_previous_rank = df[df["previous_rank"].isnull()][["....","....", "....."]]
#
# NameError: name 'df' is not defined

# %%
bigRev = MainDF["Year 1 Revenue Amount"] > 10000000
smallRev = MainDF["Year 2 Revenue Amount"] < 1222200
combined = bigRev & smallRev
MainDF[combined].head(5)
# Out:
#     Publication Date  Fiscal Year       Fundind Source Name  FPS Group  \
# 274       2016 11 17         2017                City Funds         23
# 655       2016 11 17         2017  Other Categorical Grants         30
# 855       2016 11 17         2017            Federal Grants         33
# 863       2016 11 17         2017            Federal Grants         33
# 882       2016 11 17         2017            Federal Grants         35
#
#                 FPS Group Name  Agency Number  \
# 274              Miscellaneous            2.0
# 655   Other Categorical Grants          816.0
# 855  Social Services - Federal           71.0
# 863  Social Services - Federal           71.0
# 882            Other - Federal            2.0
#
#                                  Agency Name  Revenue Category  \
# 274                                Mayoralty                24
# 655  Department of Health and Mental Hygiene                27
# 855          Department of Homeless Services                25
# ...

# %%
result1 = (MainDF["Revenue Source Name"] == "HEALTH RESEARCH") & ~(MainDF["Agency Name"] == "Department of Homeless Services")
MainDF[result1].head()
# Out:
#     Publication Date  Fiscal Year       Fundind Source Name  FPS Group  \
# 642       2016 11 17         2017  Other Categorical Grants         30
# 643       2016 11 17         2017  Other Categorical Grants         30
# 644       2016 11 17         2017  Other Categorical Grants         30
# 645       2016 11 17         2017  Other Categorical Grants         30
# 646       2016 11 17         2017  Other Categorical Grants         30
#
#                FPS Group Name  Agency Number  \
# 642  Other Categorical Grants          816.0
# 643  Other Categorical Grants          816.0
# 644  Other Categorical Grants          816.0
# 645  Other Categorical Grants          816.0
# 646  Other Categorical Grants          816.0
#
#                                  Agency Name  Revenue Category  \
# 642  Department of Health and Mental Hygiene                27
# 643  Department of Health and Mental Hygiene                27
# 644  Department of Health and Mental Hygiene                27
# ...

# %% [markdown]
# ## Sort on column

# %%
selected_rows = [MainDF["Fiscal Year"] == 2018]
sorted_rows = selected_rows.sort_values("Year 1 Revenue Amount", ascending=False)
print(sorted_rows[["Revenue Source Name", "Adopted Budget Amount"]].head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d00dbb6d9a03> in <module>()
#       1 selected_rows = [MainDF["Fiscal Year"] == 2018]
# ----> 2 sorted_rows = selected_rows.sort_values("Year 1 Revenue Amount", ascending=False)
#       3 print(sorted_rows[["Revenue Source Name", "Adopted Budget Amount"]].head())
#
# AttributeError: 'list' object has no attribute 'sort_values'

# %% [markdown]
# ## [MainDF["Fiscal Year"] == 2018] ==== List
# ## MainDF[MainDF["Fiscal Year"] == 2018] === Dataframe

# %%
selected_rows = MainDF[MainDF["Fiscal Year"] == 2018]
sorted_rows = selected_rows.sort_values("Year 1 Revenue Amount", ascending=False)
print(sorted_rows[["Revenue Source Name", "Adopted Budget Amount"]].head())

# %% [markdown]
# ## تمرین...میانگین درآمد سال اول و دوم و سوم شرکتهایی که روی محصولات سلامت تحقیقات میکنند را بدست آوردید.
# ## درآمد سالانه این شرکت هارا از بودجه تخصیص داده شده کم کنید و مجدد میانگین بگیرید.
# ## Year 1 Revenue Amount, Revenue Source Name = "HEALTH RESEARCH"
# ## کدام منبع درآمدی، بیشترین درآمد را در مجموع سه سال اول داشته است
