# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/ABA/Desktop/nikamooz/mainCourseSTuuf/dataset/baltimore-city-employee-salaries-fy2019-1.csv')
data
# Out:
#                              NAME                        JOBTITLE  DEPTID  \
# 0                  Aaron,Kareem D         Utilities Inst Repair I  A50550
# 1                Aaron,Patricia G   Facilities/Office Services II  A03031
# 2                   Abadir,Adam O              Council Technician  A02002
# 3           Abaku,Aigbolosimuan O                  Police Officer  A99094
# 4                   Abbeduto,Mack      Assistant State's Attorney  A29011
# 5                  Abbott,Ethan N      Recreation Arts Instructor  A68002
# 6            Abbott-Cole,Michelle          Operations Officer III  A90005
# 7              Abdal-Rahim,Naim A  Fire Pump Operator Suppression  A64120
# 8                  Abdi,Ezekiel W                 Police Sergeant  A99160
# 9             Abdul Adl,Attrice A        Radio Dispatcher Sheriff  A38410
# 10              Abdul Aziz,Hajr E          Swimming Pool Operator  P04002
# 11             Abdul Aziz,Yaqub M          Swimming Pool Operator  P04002
# ...

# %%
data.index.name = None
dataType = type(data)
dataShape = data.shape
dataType
# Out:
# pandas.core.frame.DataFrame

# %%
dataShape
# Out:
# (13811, 7)

# %%
data.head(6)
# Out:
#                     NAME                       JOBTITLE  DEPTID  \
# 0         Aaron,Kareem D        Utilities Inst Repair I  A50550
# 1       Aaron,Patricia G  Facilities/Office Services II  A03031
# 2          Abadir,Adam O             Council Technician  A02002
# 3  Abaku,Aigbolosimuan O                 Police Officer  A99094
# 4          Abbeduto,Mack     Assistant State's Attorney  A29011
# 5         Abbott,Ethan N     Recreation Arts Instructor  A68002
#
#                            DESCR                 HIRE_DT  ANNUAL_RT     Gross
# 0  DPW-Water & Waste Water (550)  08/27/2018 12:00:00 AM    32470.0  25743.94
# 1       OED-Employment Dev (031)  10/24/1979 12:00:00 AM    60200.0  57806.13
# 2             City Council (002)  12/12/2016 12:00:00 AM    64823.0  64774.11
# 3        Police Department (094)  04/17/2018 12:00:00 AM    53640.0  59361.55
# 4  States Attorneys Office (011)  05/22/2017 12:00:00 AM    68562.0  61693.59
# ...

# %%
data.tail(8)
# Out:
#                        NAME                      JOBTITLE  DEPTID  \
# 13803    Zoppo Jr,Phillip A              Mason Supervisor  A50509
# 13804     Zoppo,Catherine B           Real Estate Agent I  A15001
# 13805     Zorbach,Michael K                Police Officer  A99224
# 13806           Zou,Zhi Fan        Police Officer Trainee  A99163
# 13807  Zovistoski,Zachary D                Police Officer  A99006
# 13808     Zuhoski,Timothy C            Police Officer EID  A99196
# 13809        Zuniga,Linette     Community Outreach Worker  A65527
# 13810          Zyla,David C  Emergency Medical Technician  A64462
#
#                                DESCR                 HIRE_DT  ANNUAL_RT  \
# 13803  DPW-Water & Waste Water (509)  04/04/1988 12:00:00 AM    58568.0
# 13804         COMP-Real Estate (001)  03/14/1977 12:00:00 AM    64860.0
# 13805        Police Department (224)  05/02/2012 12:00:00 AM    72977.0
# 13806        Police Department (163)  04/11/2018 12:00:00 AM    53512.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13811 entries, 0 to 13810
# Data columns (total 7 columns):
# NAME         13811 non-null object
# JOBTITLE     13811 non-null object
# DEPTID       13811 non-null object
# DESCR        13811 non-null object
# HIRE_DT      13807 non-null object
# ANNUAL_RT    13811 non-null float64
# Gross        13158 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 755.4+ KB

# %% [markdown]
# ### df.loc[row_label, column_label]

# %%
JOBTITLE = data["JOBTITLE"]
aa = type(JOBTITLE)
aa
# Out:
# pandas.core.series.Series

# %%
data.loc[1, 'JOBTITLE']
# Out:
# 'Facilities/Office Services II'

# %%
data.loc[:, 'JOBTITLE']
# Out:
# 0               Utilities Inst Repair I
# 1         Facilities/Office Services II
# 2                    Council Technician
# 3                        Police Officer
# 4            Assistant State's Attorney
# 5            Recreation Arts Instructor
# 6                Operations Officer III
# 7        Fire Pump Operator Suppression
# 8                       Police Sergeant
# 9              Radio Dispatcher Sheriff
# 10               Swimming Pool Operator
# 11               Swimming Pool Operator
# 12                            Paralegal
# 13                           Engineer I
# 14           Social Service Coordinator
# 15                 Recreation Leader II
# 16        Office Support Specialist III
# 17                         911 Operator
# 18           Supt of Public Bldg Repair
# 19               Police Officer Trainee
# 20                      Printer Library
# 21                       Community Aide
# 22         Facilities/Office Services I
# ...

# %%
data.loc[:, 'JOBTITLE'].unique()
# Out:
# array(['Utilities Inst Repair I', 'Facilities/Office Services II',
#        'Council Technician', ..., 'Bike Share Program Coordinator',
#        'Tree Service Supv I', 'Lib Wide Area Network Admin'], dtype=object)

# %%
data.loc[:,['JOBTITLE','Gross']]
# Out:
#                              JOBTITLE      Gross
# 0             Utilities Inst Repair I   25743.94
# 1       Facilities/Office Services II   57806.13
# 2                  Council Technician   64774.11
# 3                      Police Officer   59361.55
# 4          Assistant State's Attorney   61693.59
# 5          Recreation Arts Instructor   26156.48
# 6              Operations Officer III   75529.99
# 7      Fire Pump Operator Suppression   82132.61
# 8                     Police Sergeant  122992.10
# 9            Radio Dispatcher Sheriff   58459.78
# 10             Swimming Pool Operator   15807.64
# 11             Swimming Pool Operator    6417.90
# 12                          Paralegal   35715.20
# 13                         Engineer I   65577.50
# 14         Social Service Coordinator   46359.55
# 15               Recreation Leader II        NaN
# 16      Office Support Specialist III   44522.96
# 17                       911 Operator   53751.88
# ...

# %%
data.loc[5:10,['JOBTITLE','Gross']]
# Out:
#                           JOBTITLE      Gross
# 5       Recreation Arts Instructor   26156.48
# 6           Operations Officer III   75529.99
# 7   Fire Pump Operator Suppression   82132.61
# 8                  Police Sergeant  122992.10
# 9         Radio Dispatcher Sheriff   58459.78
# 10          Swimming Pool Operator   15807.64

# %% [markdown]
# ## Select & Single Record

# %%
SelectData = data.loc[1:10,['JOBTITLE','Gross']]
single_record = SelectData.loc[:]
print(type(single_record))
print(single_record)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                           JOBTITLE      Gross
# 1    Facilities/Office Services II   57806.13
# 2               Council Technician   64774.11
# 3                   Police Officer   59361.55
# 4       Assistant State's Attorney   61693.59
# 5       Recreation Arts Instructor   26156.48
# 6           Operations Officer III   75529.99
# 7   Fire Pump Operator Suppression   82132.61
# 8                  Police Sergeant  122992.10
# 9         Radio Dispatcher Sheriff   58459.78
# 10          Swimming Pool Operator   15807.64

# %%
some_records =SelectData[5:10]
some_records
# Out:
#                           JOBTITLE      Gross
# 6           Operations Officer III   75529.99
# 7   Fire Pump Operator Suppression   82132.61
# 8                  Police Sergeant  122992.10
# 9         Radio Dispatcher Sheriff   58459.78
# 10          Swimming Pool Operator   15807.64

# %% [markdown]
# ## df['column']  / df.loc[rows,columns]

# %%
some_records2 =data.loc[5:10,"Gross"]
some_records2
# Out:
# 5      26156.48
# 6      75529.99
# 7      82132.61
# 8     122992.10
# 9      58459.78
# 10     15807.64
# Name: Gross, dtype: float64

# %% [markdown]
# ### Series.value_counts()
# ### مقادیر یکتا و تعداد آنها در سری

# %%
data['JOBTITLE'].value_counts()
# Out:
# Police Officer                    1474
# Laborer Hourly                     548
# Community Aide                     414
# EMT Firefighter Suppression        378
# Police Officer EID                 275
# Office Support Specialist III      271
# Crossing Guard                     249
# Police Sergeant                    237
# Recreation Arts Instructor         195
# Police Officer Trainee             192
# Assistant State's Attorney         147
# Solid Waste Worker                 143
# Motor Vehicle Driver I Hourly      135
# Firefighter Paramedic Supp         135
# Contract Srvc Specialist II        135
# Fire Lt Suppression                125
# School Health Aide 10 Mth          116
# Seasonal Maint Aide                115
# Fire Emergency Veh Drvr Supp       113
# Office Support Specialist II       111
# Police Sergeant EID                105
# Fire Pump Operator Suppression      95
# Recreation Activities Asst          93
# Transportation Enforc Off I         91
# ...

# %% [markdown]
# ## Deputy Sheriff تعداد شغل با نام

# %%
jobSeries = data['JOBTITLE'].value_counts()
jobSeries.loc['Deputy Sheriff']
# Out:
# 84

# %% [markdown]
# # حل تمرین

# %%
mydf = data.loc[100:200,['JOBTITLE','Gross','DEPTID']]
vari = mydf.loc[120:190,'DEPTID'].value_counts()
vari.max()
# Out:
# 3
