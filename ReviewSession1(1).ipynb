# %%
import pandas as pd
import numpy as np

# %%
import csv

# %% [markdown]
# # بارگذاری با ماژول پایتون و نه پانداس

# %%
f = open("C:/Users/ABA/Desktop/nikamooz/mainCourseSTuuf/dataset/Taxi.csv", "r")
taxi = list(csv.reader(f))
taxi
# Out:
# [['passenger_count',
#   'pickup_longitude',
#   'pickup_latitude',
#   'dropoff_longitude',
#   'dropoff_latitude',
#   'trip_duration'],
#  ['1', '-73.98215485', '40.76793671', '-73.96463013', '40.76560211', '455'],
#  ['1', '-73.98041534', '40.73856354', '-73.9994812', '40.73115158', '663'],
#  ['1', '-73.97902679', '40.7639389', '-74.00533295', '40.71008682', '2124'],
#  ['1', '-74.01004028', '40.7199707', '-74.01226807', '40.70671844', '429'],
#  ['1', '-73.97305298', '40.79320908', '-73.97292328', '40.78252029', '435'],
#  ['6', '-73.98285675', '40.74219513', '-73.99208069', '40.74918365', '443'],
#  ['4', '-73.96901703', '40.7578392', '-73.95740509', '40.76589584', '341'],
#  ['1', '-73.96927643', '40.79777908', '-73.92247009', '40.76055908', '1551'],
#  ['1', '-73.9994812', '40.73839951', '-73.98578644', '40.73281479', '255'],
#  ['1', '-73.98104858', '40.74433899', '-73.97299957', '40.78998947', '1225'],
# ...

# %%
type(taxi)
# Out:
# list

# %%
taxi[1:5]
# Out:
# [['1', '-73.98215485', '40.76793671', '-73.96463013', '40.76560211', '455'],
#  ['1', '-73.98041534', '40.73856354', '-73.9994812', '40.73115158', '663'],
#  ['1', '-73.97902679', '40.7639389', '-74.00533295', '40.71008682', '2124'],
#  ['1', '-74.01004028', '40.7199707', '-74.01226807', '40.70671844', '429']]

# %% [markdown]
# ## علت خطا در پایین چیست؟

# %%
taxi[1:10,1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7da0f4a6225c> in <module>()
# ----> 1 taxi[1:10,1:]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# ## نوع تاکسی چیست؟

# %%
type(taxi)
# Out:
# list

# %% [markdown]
# # تبدیل لیست تاکسی به نامپای

# %%
taxi = np.array(taxi)

# %% [markdown]
# ## سطر یک تا پنج

# %%
taxi[1:5]
# Out:
# array([['1', '-73.98215485', '40.76793671', '-73.96463013',
#         '40.76560211', '455'],
#        ['1', '-73.98041534', '40.73856354', '-73.9994812', '40.73115158',
#         '663'],
#        ['1', '-73.97902679', '40.7639389', '-74.00533295', '40.71008682',
#         '2124'],
#        ['1', '-74.01004028', '40.7199707', '-74.01226807', '40.70671844',
#         '429']], dtype='<U17')

# %%
taxi[1:3,2:5]
# Out:
# array([['40.76793671', '-73.96463013', '40.76560211'],
#        ['40.73856354', '-73.9994812', '40.73115158']], dtype='<U17')

# %% [markdown]
# ## نوشتن متفاوت

# %%
taxi[2,[1,2]]
# Out:
# array(['-73.98041534', '40.73856354'], dtype='<U17')

# %% [markdown]
# ## علت خطای پایین چیست؟

# %%
taxisum = taxi[:,0]
taxisum.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-35edfe69e3fd> in <module>()
#       1 taxisum = taxi[:,0]
# ----> 2 taxisum.sum()
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: cannot perform reduce with flexible type

# %% [markdown]
# # علت خطای پایین چیست

# %%
taxisum = taxi[:,2].astype(float)
taxisum.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-fb2a0086716f> in <module>()
# ----> 1 taxisum = taxi[:,2].astype(float)
#       2 taxisum.sum()
#
# ValueError: could not convert string to float: 'pickup_latitude'

# %% [markdown]
# ## تغییر موفق نوع داده به اعشاری

# %%
taxisum = taxi[2:,2].astype(float)
taxisum.sum()
# Out:
# 42730378.239756405

# %% [markdown]
# ## تقسیم طول مدت سفر بر تعداد مسافر جهت محاسبه هزینه هر نفر

# %%
(taxi[1:,5].astype(float))/(taxi[1:,1].astype(float))
# Out:
# array([ -6.15013176,  -8.96183128, -28.71083998, ...,  -8.17876611,
#         -3.87872789, -15.79984662])

# %% [markdown]
# ## خواندن با پانداس و دیتا فریم

# %%
MainDF = pd.read_csv('C:/Users/ABA/Desktop/nikamooz/mainCourseSTuuf/dataset/revenue-budget-financial-plan.csv')
MainDF.head(10)
# Out:
#   Publication Date  Fiscal Year Fundind Source Name  FPS Group  \
# 0       2016 11 17         2017          City Funds          1
# 1       2016 11 17         2017          City Funds          1
# 2       2016 11 17         2017          City Funds          1
# 3       2016 11 17         2017          City Funds          1
# 4       2016 11 17         2017          City Funds          1
# 5       2016 11 17         2017          City Funds          1
# 6       2016 11 17         2017          City Funds          1
# 7       2016 11 17         2017          City Funds          2
# 8       2016 11 17         2017          City Funds          2
# 9       2016 11 17         2017          City Funds          3
#
#         FPS Group Name  Agency Number Agency Name  Revenue Category  \
# 0        Real Property            2.0   Mayoralty                20
# 1        Real Property            2.0   Mayoralty                20
# ...

# %% [markdown]
# ## اسامی هدر ها یا فیچر ها

# %%
MainDF.columns
# Out:
# Index(['Publication Date', 'Fiscal Year', 'Fundind Source Name', 'FPS Group',
#        'FPS Group Name', 'Agency Number', 'Agency Name', 'Revenue Category',
#        'Revenue Category Name', 'Revenue Class Code', 'Revenue Class Name',
#        'Budget Code', 'Revenue Source', 'Revenue Source Name',
#        'Revenue Structure Description', 'Adopted Budget Amount',
#        'Current Modified Budget Amount', 'Yr1_FY', 'Year 1 Revenue Amount',
#        'Year 2 Revenue Amount', 'Year 3 Revenue Amount',
#        'Year 4 Revenue Amount'],
#       dtype='object')

# %%
MainDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3213 entries, 0 to 3212
# Data columns (total 22 columns):
# Publication Date                  3213 non-null object
# Fiscal Year                       3213 non-null int64
# Fundind Source Name               3213 non-null object
# FPS Group                         3213 non-null int64
# FPS Group Name                    3213 non-null object
# Agency Number                     3213 non-null float64
# Agency Name                       3213 non-null object
# Revenue Category                  3213 non-null int64
# Revenue Category Name             3213 non-null object
# Revenue Class Code                3213 non-null float64
# Revenue Class Name                3213 non-null object
# Budget Code                       3213 non-null object
# Revenue Source                    3213 non-null object
# Revenue Source Name               3213 non-null object
# Revenue Structure Description     3213 non-null object
# ...

# %% [markdown]
# ## آمار ابتدایی داده

# %%
MainDF.describe()
# Out:
#        Fiscal Year    FPS Group  Agency Number  Revenue Category  \
# count  3213.000000  3213.000000    3213.000000       3213.000000
# mean   2017.502646    29.889200     504.031435         25.044818
# std       0.500071     7.591381     385.724378          5.592746
# min    2017.000000     1.000000       2.000000         20.000000
# 25%    2017.000000    24.000000      56.000000         22.000000
# 50%    2018.000000    33.000000     806.000000         25.000000
# 75%    2018.000000    35.000000     841.000000         26.000000
# max    2018.000000    40.000000     945.000000         90.000000
#
#        Revenue Class Code  Adopted Budget Amount  \
# count         3213.000000           3.213000e+03
# mean           166.804544           5.320068e+07
# std            157.439135           5.761721e+08
# min              1.000000          -1.130000e+09
# 25%             13.000000           0.000000e+00
# 50%            210.000000           2.312620e+05
# ...

# %% [markdown]
# ## استفاده از تابع اشتباه برای دیتا فریم

# %%
MainDF.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-20ed061085f8> in <module>()
# ----> 1 MainDF.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %% [markdown]
# ## تابع صحیح مقادیر یکتا در سریز

# %%
MainDF['Fiscal Year'].value_counts()
# Out:
# 2018    1615
# 2017    1598
# Name: Fiscal Year, dtype: int64

# %% [markdown]
# ## تابع تعداد مقادیر یکتا در دیتافریم

# %%
MainDF.nunique()
# Out:
# Publication Date                     2
# Fiscal Year                          2
# Fundind Source Name                  7
# FPS Group                           35
# FPS Group Name                      35
# Agency Number                       78
# Agency Name                         78
# Revenue Category                    12
# Revenue Category Name               14
# Revenue Class Code                  71
# Revenue Class Name                  66
# Budget Code                       1136
# Revenue Source                     583
# Revenue Source Name                561
# Revenue Structure Description     1635
# Adopted Budget Amount             1442
# Current Modified Budget Amount    2316
# Yr1_FY                               2
# Year 1 Revenue Amount             2334
# Year 2 Revenue Amount             1318
# Year 3 Revenue Amount             1252
# Year 4 Revenue Amount             1227
# dtype: int64

# %%
MainDF['Fiscal Year'].head(5)
# Out:
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# Name: Fiscal Year, dtype: int64

# %%
MainDF['Fiscal Year']

# %%
MainDF['Fiscal Year'] + 10
# Out:
# 0       2027
# 1       2027
# 2       2027
# 3       2027
# 4       2027
# 5       2027
# 6       2027
# 7       2027
# 8       2027
# 9       2027
# 10      2027
# 11      2027
# 12      2027
# 13      2027
# 14      2027
# 15      2027
# 16      2027
# 17      2027
# 18      2027
# 19      2027
# 20      2027
# 21      2027
# 22      2027
# 23      2027
# 24      2027
# 25      2027
# 26      2027
# 27      2027
# 28      2027
# 29      2027
#         ...
# 3183    2028
# 3184    2028
# 3185    2028
# 3186    2028
# 3187    2028
# 3188    2028
# 3189    2028
# 3190    2028
# 3191    2028
# 3192    2028
# 3193    2028
# 3194    2028
# 3195    2028
# 3196    2028
# 3197    2028
# 3198    2028
# 3199    2028
# 3200    2028
# 3201    2028
# 3202    2028
# 3203    2028
# 3204    2028
# 3205    2028
# 3206    2028
# 3207    2028
# 3208    2028
# 3209    2028
# 3210    2028
# 3211    2028
# 3212    2028
# Name: Fiscal Year, Length: 3213, dtype: int64

# %%
ekhtelaf = MainDF['Year 3 Revenue Amount'] - MainDF['Year 1 Revenue Amount'] 
ekhtelaf.head(10)
# Out:
# 0    1243605000
# 1     218742000
# 2    1198858000
# 3     223924000
# 4             0
# 5             0
# 6      10000000
# 7     834000000
# 8     -47000000
# 9     279000000
# dtype: int64

# %% [markdown]
# # اضافه کردن ستون اختلاف درامد

# %%
MainDF['Ekhtelaf3&1'] = ekhtelaf
MainDF.head(10)
# Out:
#   Publication Date  Fiscal Year Fundind Source Name  FPS Group  \
# 0       2016 11 17         2017          City Funds          1
# 1       2016 11 17         2017          City Funds          1
# 2       2016 11 17         2017          City Funds          1
# 3       2016 11 17         2017          City Funds          1
# 4       2016 11 17         2017          City Funds          1
# 5       2016 11 17         2017          City Funds          1
# 6       2016 11 17         2017          City Funds          1
# 7       2016 11 17         2017          City Funds          2
# 8       2016 11 17         2017          City Funds          2
# 9       2016 11 17         2017          City Funds          3
#
#         FPS Group Name  Agency Number Agency Name  Revenue Category  \
# 0        Real Property            2.0   Mayoralty                20
# 1        Real Property            2.0   Mayoralty                20
# ...

# %%
MainDF['Ekhtelaf3&1'].mean()
# Out:
# 2684509.6100217863

# %%
MainDF['Ekhtelaf3&1'].min()
# Out:
# -1347445699

# %% [markdown]
# ## به تفاوت مقیاس واریانس و انحراف از معیار دقت کنید

# %%
MainDF['Ekhtelaf3&1'].var()
# Out:
# 4383713252802201.0

# %%
MainDF['Ekhtelaf3&1'].std()
# Out:
# 66209616.01461075

# %%
MainDF['Ekhtelaf3&1'].describe()
# Out:
# count    3.213000e+03
# mean     2.684510e+06
# std      6.620962e+07
# min     -1.347446e+09
# 25%     -1.710490e+05
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.279039e+09
# Name: Ekhtelaf3&1, dtype: float64

# %%
MainDF.loc[:,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-946433a0ebc9> in <module>()
# ----> 1 MainDF.loc[:,2]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     996         for i, key in enumerate(tup):
# ...

# %%
MainDF.iloc[:,'Fiscal Year']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1970             raise ValueError("Can only index by location with "
# -> 1971                              "a [{types}]".format(types=self._valid_types))
#    1972
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-88f80aee58c6> in <module>()
# ...

# %%
MainDF.loc[:,'Fiscal Year']
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2017
# 4       2017
# 5       2017
# 6       2017
# 7       2017
# 8       2017
# 9       2017
# 10      2017
# 11      2017
# 12      2017
# 13      2017
# 14      2017
# 15      2017
# 16      2017
# 17      2017
# 18      2017
# 19      2017
# 20      2017
# 21      2017
# 22      2017
# 23      2017
# 24      2017
# 25      2017
# 26      2017
# 27      2017
# 28      2017
# 29      2017
#         ...
# 3183    2018
# 3184    2018
# 3185    2018
# 3186    2018
# 3187    2018
# 3188    2018
# 3189    2018
# 3190    2018
# 3191    2018
# 3192    2018
# 3193    2018
# 3194    2018
# 3195    2018
# 3196    2018
# 3197    2018
# 3198    2018
# 3199    2018
# 3200    2018
# 3201    2018
# 3202    2018
# 3203    2018
# 3204    2018
# 3205    2018
# 3206    2018
# 3207    2018
# 3208    2018
# 3209    2018
# 3210    2018
# 3211    2018
# 3212    2018
# Name: Fiscal Year, Length: 3213, dtype: int64

# %% [markdown]
# ## منبع درامد های شهری

# %%
MainDF["Fundind Source Name"].value_counts()
# Out:
# Federal Grants              1043
# City Funds                   696
# State Grants                 566
# Intra-City                   436
# Other Categorical Grants     426
# Inter Fund Agreements         40
# Community Development          6
# Name: Fundind Source Name, dtype: int64

# %%
MainDF["Fundind Source Name"].value_counts().loc["City Funds"]
# Out:
# 696

# %%
bigRev = MainDF["Year 1 Revenue Amount"] > 10000000
smallRev = MainDF["Year 2 Revenue Amount"] < 1222200
combined = bigRev & smallRev
MainDF[combined].head(5)
# Out:
#     Publication Date  Fiscal Year       Fundind Source Name  FPS Group  \
# 274       2016 11 17         2017                City Funds         23
# 655       2016 11 17         2017  Other Categorical Grants         30
# 855       2016 11 17         2017            Federal Grants         33
# 863       2016 11 17         2017            Federal Grants         33
# 882       2016 11 17         2017            Federal Grants         35
#
#                 FPS Group Name  Agency Number  \
# 274              Miscellaneous            2.0
# 655   Other Categorical Grants          816.0
# 855  Social Services - Federal           71.0
# 863  Social Services - Federal           71.0
# 882            Other - Federal            2.0
#
#                                  Agency Name  Revenue Category  \
# 274                                Mayoralty                24
# 655  Department of Health and Mental Hygiene                27
# 855          Department of Homeless Services                25
# ...

# %% [markdown]
# ##  عملیات سطری

# %%
means = MainDF[['Year 1 Revenue Amount','Year 2 Revenue Amount']].mean(axis=0)
means.head(5)
